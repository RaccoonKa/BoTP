# %%
import requests
import time
import csv
from bs4 import BeautifulSoup
from random import uniform

BASE_URL = "https://books.toscrape.com/catalogue/page-{}.html"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}

def get_rating(tag):
    classes = tag.get("class", [])
    ratings = ["One", "Two", "Three", "Four", "Five"]
    for r in ratings:
        if r in classes:
            return r
    return None


all_books = []

with open("books.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["title", "price", "rating", "availability"])

for page in range(1, 51):

    url = BASE_URL.format(page)
    print(f"Страница {page}: {url}")

    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        resp.raise_for_status()
    except Exception as e:
        print("Ошибка запроса:", e)
        print("Пауза и продолжаем...")
        time.sleep(5)
        continue

    soup = BeautifulSoup(resp.text, "html.parser")
    books = soup.find_all("article", class_="product_pod")

    page_data = []

    for b in books:
        title = b.h3.a["title"]
        price = b.find("p", class_="price_color").text
        availability = b.find("p", class_="instock availability").text.strip()
        rating = get_rating(b.find("p", class_="star-rating"))

        page_data.append([title, price, rating, availability])

    # сохранение после каждой страницы
    with open("books.csv", "a", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerows(page_data)

    all_books.extend(page_data)

    # задержка
    sleep_time = uniform(1.5, 3.5)
    print(f"Сохранено {len(page_data)} книг. Сон {sleep_time:.2f} сек\n")
    time.sleep(sleep_time)

print("Готово! Всего книг:", len(all_books))
# Out:
# Страница 1: https://books.toscrape.com/catalogue/page-1.html
# Сохранено 20 книг. Сон 2.52 сек
#
# Страница 2: https://books.toscrape.com/catalogue/page-2.html
# Сохранено 20 книг. Сон 2.33 сек
#
# Страница 3: https://books.toscrape.com/catalogue/page-3.html
# Сохранено 20 книг. Сон 3.11 сек
#
# Страница 4: https://books.toscrape.com/catalogue/page-4.html
# Сохранено 20 книг. Сон 1.59 сек
#
# Страница 5: https://books.toscrape.com/catalogue/page-5.html
# Сохранено 20 книг. Сон 1.92 сек
#
# Страница 6: https://books.toscrape.com/catalogue/page-6.html
# Сохранено 20 книг. Сон 2.28 сек
#
# Страница 7: https://books.toscrape.com/catalogue/page-7.html
# Сохранено 20 книг. Сон 2.82 сек
#
# Страница 8: https://books.toscrape.com/catalogue/page-8.html
# Сохранено 20 книг. Сон 2.66 сек
#
# Страница 9: https://books.toscrape.com/catalogue/page-9.html
# Сохранено 20 книг. Сон 2.25 сек
#
# Страница 10: https://books.toscrape.com/catalogue/page-10.html
# Сохранено 20 книг. Сон 2.61 сек
#
# Страница 11: https://books.toscrape.com/catalogue/page-11.html
# Сохранено 20 книг. Сон 2.28 сек
#
# Страница 12: https://books.toscrape.com/catalogue/page-12.html
# Сохранено 20 книг. Сон 1.50 сек
#
# Страница 13: https://books.toscrape.com/catalogue/page-13.html
# Сохранено 20 книг. Сон 2.82 сек
#
# Страница 14: https://books.toscrape.com/catalogue/page-14.html
# Сохранено 20 книг. Сон 3.19 сек
#
# Страница 15: https://books.toscrape.com/catalogue/page-15.html
# Сохранено 20 книг. Сон 1.92 сек
#
# Страница 16: https://books.toscrape.com/catalogue/page-16.html
# Сохранено 20 книг. Сон 3.06 сек
#
# Страница 17: https://books.toscrape.com/catalogue/page-17.html
# Сохранено 20 книг. Сон 1.82 сек
#
# Страница 18: https://books.toscrape.com/catalogue/page-18.html
# Сохранено 20 книг. Сон 3.38 сек
#
# Страница 19: https://books.toscrape.com/catalogue/page-19.html
# Сохранено 20 книг. Сон 2.35 сек
#
# Страница 20: https://books.toscrape.com/catalogue/page-20.html
# Сохранено 20 книг. Сон 2.68 сек
#
# Страница 21: https://books.toscrape.com/catalogue/page-21.html
# Сохранено 20 книг. Сон 3.09 сек
#
# Страница 22: https://books.toscrape.com/catalogue/page-22.html
# Сохранено 20 книг. Сон 2.97 сек
#
# Страница 23: https://books.toscrape.com/catalogue/page-23.html
# Сохранено 20 книг. Сон 1.68 сек
#
# Страница 24: https://books.toscrape.com/catalogue/page-24.html
# Сохранено 20 книг. Сон 3.16 сек
#
# Страница 25: https://books.toscrape.com/catalogue/page-25.html
# Сохранено 20 книг. Сон 1.78 сек
#
# Страница 26: https://books.toscrape.com/catalogue/page-26.html
# Сохранено 20 книг. Сон 3.36 сек
#
# Страница 27: https://books.toscrape.com/catalogue/page-27.html
# Сохранено 20 книг. Сон 1.57 сек
#
# Страница 28: https://books.toscrape.com/catalogue/page-28.html
# Сохранено 20 книг. Сон 1.64 сек
#
# Страница 29: https://books.toscrape.com/catalogue/page-29.html
# Сохранено 20 книг. Сон 1.53 сек
#
# Страница 30: https://books.toscrape.com/catalogue/page-30.html
# Сохранено 20 книг. Сон 2.24 сек
#
# Страница 31: https://books.toscrape.com/catalogue/page-31.html
# Сохранено 20 книг. Сон 2.59 сек
#
# Страница 32: https://books.toscrape.com/catalogue/page-32.html
# Сохранено 20 книг. Сон 2.93 сек
#
# Страница 33: https://books.toscrape.com/catalogue/page-33.html
# Сохранено 20 книг. Сон 2.07 сек
#
# Страница 34: https://books.toscrape.com/catalogue/page-34.html
# Сохранено 20 книг. Сон 2.92 сек
#
# Страница 35: https://books.toscrape.com/catalogue/page-35.html
# Сохранено 20 книг. Сон 2.04 сек
#
# Страница 36: https://books.toscrape.com/catalogue/page-36.html
# Сохранено 20 книг. Сон 2.57 сек
#
# Страница 37: https://books.toscrape.com/catalogue/page-37.html
# Сохранено 20 книг. Сон 2.47 сек
#
# Страница 38: https://books.toscrape.com/catalogue/page-38.html
# Сохранено 20 книг. Сон 1.53 сек
#
# Страница 39: https://books.toscrape.com/catalogue/page-39.html
# Сохранено 20 книг. Сон 2.29 сек
#
# Страница 40: https://books.toscrape.com/catalogue/page-40.html
# Сохранено 20 книг. Сон 3.35 сек
#
# Страница 41: https://books.toscrape.com/catalogue/page-41.html
# Сохранено 20 книг. Сон 3.43 сек
#
# Страница 42: https://books.toscrape.com/catalogue/page-42.html
# Сохранено 20 книг. Сон 2.91 сек
#
# Страница 43: https://books.toscrape.com/catalogue/page-43.html
# Сохранено 20 книг. Сон 3.17 сек
#
# Страница 44: https://books.toscrape.com/catalogue/page-44.html
# Сохранено 20 книг. Сон 2.28 сек
#
# Страница 45: https://books.toscrape.com/catalogue/page-45.html
# Сохранено 20 книг. Сон 2.53 сек
#
# Страница 46: https://books.toscrape.com/catalogue/page-46.html
# Сохранено 20 книг. Сон 2.78 сек
#
# Страница 47: https://books.toscrape.com/catalogue/page-47.html
# Сохранено 20 книг. Сон 3.09 сек
#
# Страница 48: https://books.toscrape.com/catalogue/page-48.html
# Сохранено 20 книг. Сон 1.59 сек
#
# Страница 49: https://books.toscrape.com/catalogue/page-49.html
# Сохранено 20 книг. Сон 3.47 сек
#
# Страница 50: https://books.toscrape.com/catalogue/page-50.html
# Сохранено 20 книг. Сон 2.25 сек
#
# Готово! Всего книг: 1000
